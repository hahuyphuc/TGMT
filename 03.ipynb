# %%
# Import lớp Image
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
# Đường dẫn ảnh
path = 'C:/Users/huyph/Documents/TGMT/IMG/03.jpg'

# %%
# Đọc ảnh 
img = load_image(path)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=168x299>

# %%
# Kích thước ban đầu:
print(img.size)
# Out:
# (168, 299)

# %%
# Thay đổi kích thước
new_size = (500,500)
new_image = img.resize(new_size)
display(new_image)
# Task: lưu ảnh
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
# Thay đổi kích thước
thumbnail_size = (100,100)
img.thumbnail(thumbnail_size)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=28x50>
