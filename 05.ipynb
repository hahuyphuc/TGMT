# %%
# Import lớp Image
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
# Đường dẫn ảnh
path = 'C:/Users/huyph/Documents/TGMT/IMG/05.jpg'

# %%
# Đọc ảnh 
img = load_image(path)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=201x251>

# %%
# Xoay ảnh
rotated_image = img.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=201x251>

# %%
# Transpose ảnh
transposed_image = img.transpose(Image.Transpose.ROTATE_90)
display(transposed_image)
# Out:
# <PIL.Image.Image image mode=RGB size=251x201>
