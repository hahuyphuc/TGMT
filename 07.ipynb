# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image

# %%
path = 'C:/Users/huyph/Documents/TGMT/IMG/07.jpg'

# %%
# Đọc ảnh và hiển thị
im = Image.open(path)
# display(im)
plt.imshow(im)

# %%
# Vẽ đồ thị cơ bản
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y)
plt.show()

# %%
plt.plot(x, y, color='red')
plt.show()

# %%
plt.plot(x, y, color='red') # Màu sắc
plt.title('Ví dụ về biểu đồ') # Title
plt.show()

# %%
# Tắt hệ trục tọa độ
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y, color='red')  # Thay đổi màu thành đỏ
plt.title('Biểu đồ ví dụ với màu đỏ')  # Thêm tiêu đề
# Tắt hệ trục tọa độ
plt.axis('off')  # Tắt hệ trục tọa độ
plt.show()

# %%
# Vẽ trên hình ảnh
# ĐỌc ảnh
im = Image.open(path)
x = [100, 100, 400, 400]
y = [200, 300, 200, 300]
plt.imshow(im) # Hiển thị hình ảnh
plt.plot(x,y, 'bo--') 
plt.show()
