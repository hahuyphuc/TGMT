# %%
# Import lớp Image
from PIL import Image
from imgtools import *
from IPython.display import display # to display images

# %%
dir ='C:/Users/huyph/Documents/TGMT/IMG'

# %%
# Đọc nhiều ảnh
imgs=get_image_list(dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (201, 251)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=201x251>
# (201, 250)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=201x250>
# (168, 299)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=168x299>
# (168, 300)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=168x300>
# (201, 251)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=201x251>
# (201, 251)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=201x251>
