# %%
# Shift + Enter: run code + add row

# %%
# Cài đặt
# !pip install Pillow
# !conda install Pillow

# %%
# Import lớp Image
from PIL import Image

# %%
# Thư mục chứa hình ảnh
dir = 'C:/Users/huyph/Documents/TGMT/IMG'

# %%
# Đường dẫn đến hình ảnh
image_path = dir +'/01.JPG'
print(image_path)
# Out:
# C:/Users/huyph/Documents/TGMT/IMG/01.JPG

# %%
# Sử dụng Image.open() đọc ảnh
img01 = Image.open(image_path)

# %%
# Hiển thị hình ảnh
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=201x251>

# %%
# In một số thông tin
# In định dạng ảnh
print("Định dang ảnh: ", img01.format)
# Out:
# Định dang ảnh:  JPEG

# %%
# In ra size
print("Kích thước hình ảnh: ", img01.size)
# Out:
# Kích thước hình ảnh:  (201, 251)

# %%
# Lưu ảnh và chuyển đổi ảnh
new_img_01_path = dir + '/new_01.JPG'
new_img_png_01_path = dir + '/new_01.PNG'
img01.save(new_img_01_path)
img01.save(new_img_png_01_path)

# %%
# Đóng tập tin
img01.close()
